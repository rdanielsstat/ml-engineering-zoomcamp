# %%
import pickle
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, TargetEncoder
from sklearn.feature_selection import mutual_info_regression
from importlib.metadata import version

print("Pandas version: " + str(pd.__version__))
print("Numpy version: " + str(np.__version__))
print("Scikit-learn version: " + str(version("scikit-learn")))
# Out:
# Pandas version: 2.3.3
# Numpy version: 2.3.4
# Scikit-learn version: 1.7.2

# %%
# load post-eda data and mappings
with open('../data/temp/eda_output.pkl', 'rb') as f:
    eda_data = pickle.load(f)

df = eda_data['data']
category_mappings = eda_data['category_mappings']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7213 entries, 0 to 7212
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   health_service_area                  7213 non-null   object
#  1   hospital_county                      7213 non-null   object
#  2   permanent_facility_id                7213 non-null   object
#  3   age_group                            7213 non-null   object
#  4   zip_code                             7213 non-null   object
#  5   gender                               7213 non-null   object
#  6   race                                 7213 non-null   object
#  7   ethnicity                            7213 non-null   object
#  8   length_of_stay                       7213 non-null   int64
#  9   type_of_admission                    7213 non-null   object
#  10  patient_disposition                  7213 non-null   object
#  11  ccsr_procedure_description           7213 non-null   object
#  12  apr_drg_description                  7213 non-null   object
#  13  apr_mdc_description                  7213 non-null   object
#  14  apr_severity_of_illness_description  7213 non-null   object
#  15  apr_risk_of_mortality                7213 non-null   object
#  16  apr_medical_surgical_description     7213 non-null   object
#  17  payment_typology_1                   7213 non-null   object
#  18  payment_typology_2                   7213 non-null   object
#  19  payment_typology_3                   7213 non-null   object
#  20  emergency_department_indicator       7213 non-null   object
#  21  log_length_of_stay                   7213 non-null   float64
# dtypes: float64(1), int64(1), object(20)
# memory usage: 1.2+ MB

# %%
df.describe(include = 'all').T
# Out:
#                                       count unique  \
# health_service_area                    7213      8
# hospital_county                        7213     33
# permanent_facility_id                  7213    116
# age_group                              7213      5
# zip_code                               7213     49
# gender                                 7213      2
# race                                   7213      4
# ethnicity                              7213      3
# length_of_stay                       7213.0    NaN
# type_of_admission                      7213      3
# patient_disposition                    7213     11
# ccsr_procedure_description             7213     20
# apr_drg_description                    7213      4
# apr_mdc_description                    7213      3
# apr_severity_of_illness_description    7213      4
# apr_risk_of_mortality                  7213      4
# apr_medical_surgical_description       7213      2
# payment_typology_1                     7213      7
# payment_typology_2                     7213      9
# payment_typology_3                     7213      6
# emergency_department_indicator         7213      2
# log_length_of_stay                   7213.0    NaN
#
#                                                                                    top  \
# health_service_area                                                      New York City
# hospital_county                                                               New York
# permanent_facility_id                                                            Other
# age_group                                                                  70 or Older
# zip_code                                                                           112
# gender                                                                             F/U
# race                                                                             White
# ethnicity                                                            Not Span/Hispanic
# length_of_stay                                                                     NaN
# type_of_admission                                                            Emergency
# patient_disposition                                                  Home or Self Care
# ccsr_procedure_description                                                        None
# apr_drg_description                              INFECTIONS OF UPPER RESPIRATORY TRACT
# apr_mdc_description                  EAR, NOSE, MOUTH, THROAT AND CRANIOFACIAL DISE...
# apr_severity_of_illness_description                                              Major
# apr_risk_of_mortality                                                            Major
# apr_medical_surgical_description                                               Medical
# payment_typology_1                                                            Medicare
# payment_typology_2                                                                None
# payment_typology_3                                                                None
# emergency_department_indicator                                                       Y
# log_length_of_stay                                                                 NaN
#
#                                      freq      mean       std  min       25%  \
# health_service_area                  3463       NaN       NaN  NaN       NaN
# hospital_county                       977       NaN       NaN  NaN       NaN
# permanent_facility_id                 485       NaN       NaN  NaN       NaN
# age_group                            3470       NaN       NaN  NaN       NaN
# zip_code                              970       NaN       NaN  NaN       NaN
# gender                               4017       NaN       NaN  NaN       NaN
# race                                 3613       NaN       NaN  NaN       NaN
# ethnicity                            5147       NaN       NaN  NaN       NaN
# length_of_stay                        NaN  4.653681  6.185733  1.0       2.0
# type_of_admission                    6945       NaN       NaN  NaN       NaN
# patient_disposition                  4508       NaN       NaN  NaN       NaN
# ccsr_procedure_description           3373       NaN       NaN  NaN       NaN
# apr_drg_description                  4674       NaN       NaN  NaN       NaN
# apr_mdc_description                  4700       NaN       NaN  NaN       NaN
# apr_severity_of_illness_description  3327       NaN       NaN  NaN       NaN
# apr_risk_of_mortality                2622       NaN       NaN  NaN       NaN
# apr_medical_surgical_description     7151       NaN       NaN  NaN       NaN
# payment_typology_1                   4308       NaN       NaN  NaN       NaN
# payment_typology_2                   3125       NaN       NaN  NaN       NaN
# payment_typology_3                   6040       NaN       NaN  NaN       NaN
# emergency_department_indicator       6717       NaN       NaN  NaN       NaN
# log_length_of_stay                    NaN  1.174622   0.80108  0.0  0.693147
#
#                                           50%       75%       max
# health_service_area                       NaN       NaN       NaN
# hospital_county                           NaN       NaN       NaN
# permanent_facility_id                     NaN       NaN       NaN
# age_group                                 NaN       NaN       NaN
# zip_code                                  NaN       NaN       NaN
# gender                                    NaN       NaN       NaN
# race                                      NaN       NaN       NaN
# ethnicity                                 NaN       NaN       NaN
# length_of_stay                            3.0       5.0     120.0
# type_of_admission                         NaN       NaN       NaN
# patient_disposition                       NaN       NaN       NaN
# ccsr_procedure_description                NaN       NaN       NaN
# apr_drg_description                       NaN       NaN       NaN
# apr_mdc_description                       NaN       NaN       NaN
# apr_severity_of_illness_description       NaN       NaN       NaN
# apr_risk_of_mortality                     NaN       NaN       NaN
# apr_medical_surgical_description          NaN       NaN       NaN
# payment_typology_1                        NaN       NaN       NaN
# payment_typology_2                        NaN       NaN       NaN
# payment_typology_3                        NaN       NaN       NaN
# emergency_department_indicator            NaN       NaN       NaN
# log_length_of_stay                   1.098612  1.609438  4.787492

# %% [markdown]
# Due to the right-skewed distribution of length of stay, a log transformation was applied to the target variable for modeling. Predictions will be transformed back to the original scale for evaluation.

# %%
# split into 80/10/10
X = df.drop(columns = ['length_of_stay', 'log_length_of_stay'])
y = df['log_length_of_stay']

X_train_val, X_test, y_train_val, y_test = train_test_split(
    X, y, test_size = 0.1, random_state = 42
)

X_train, X_val, y_train, y_val = train_test_split(
    X_train_val, y_train_val, test_size = 0.1111111, random_state = 42  # 0.1 / 0.9 = 0.1111111
)

len(X_train), len(X_val), len(X_test)
# Out:
# (5769, 722, 722)

# %%
# all columns in X train are categorical
features = ['health_service_area', 'hospital_county', 'permanent_facility_id',
            'age_group', 'zip_code', 'gender', 
            'race', 'ethnicity', 'type_of_admission', 
            'patient_disposition', 'ccsr_procedure_description', 'apr_drg_description', 
            'apr_mdc_description', 'apr_severity_of_illness_description', 'apr_risk_of_mortality', 
            'apr_medical_surgical_description', 'payment_typology_1', 'payment_typology_2', 
            'payment_typology_3', 'emergency_department_indicator']

# %%
# simple differences and ratios analysis (effect sizes analysis)
def categorical_features_summary(X, y, features, decimals=4):
    global_mean = round(float(y.mean()), decimals)
    df = X.copy()
    df['_target_'] = y.values
    
    for col in features:
        grouped = df.groupby(col)['_target_'].agg(['count', 'mean'])
        grouped = grouped.rename(columns={'mean': 'target_mean'})
        
        # Add percentage column
        total_count = grouped['count'].sum()
        grouped['percent'] = (grouped['count'] / total_count * 100).round(2)
        
        grouped['target_mean'] = grouped['target_mean'].round(decimals)
        grouped['diff_from_global_mean'] = (grouped['target_mean'] - global_mean).round(decimals)
        grouped['ratio_to_global_mean'] = (grouped['target_mean'] / global_mean).round(decimals)
        
        summary = grouped.reset_index()
        summary = summary.sort_values('target_mean', ascending=False)
        
        print(f"--- {col} ---")
        print(summary.to_string(index=False), "\n")

# %%
categorical_features_summary(
    X = X_train,
    y = y_train,
    features = features,
    decimals = 4
)
# Out:
# --- health_service_area ---
# health_service_area  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#       Hudson Valley    623       1.2980    10.80                 0.1238                1.1054
# Capital/Adirondacks    275       1.2376     4.77                 0.0634                1.0540
#        Finger Lakes    393       1.2258     6.81                 0.0516                1.0439
#          Central NY    260       1.1960     4.51                 0.0218                1.0186
#          Western NY    388       1.1672     6.73                -0.0070                0.9940
#         Long Island    989       1.1499    17.14                -0.0243                0.9793
# Southern Tier/Other     67       1.1477     1.16                -0.0265                0.9774
#       New York City   2774       1.1411    48.08                -0.0331                0.9718
#
# --- hospital_county ---
# hospital_county  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#          Oneida     40       1.4800     0.69                 0.3058                1.2604
#        Rockland     56       1.3750     0.97                 0.2008                1.1710
#         Ontario     40       1.3622     0.69                 0.1880                1.1601
#          Otsego     21       1.3414     0.36                 0.1672                1.1424
#         Niagara     35       1.3410     0.61                 0.1668                1.1421
#          Orange    109       1.3314     1.89                 0.1572                1.1339
#           Kings    684       1.3277    11.86                 0.1535                1.1307
#        Dutchess     80       1.3230     1.39                 0.1488                1.1267
#          Monroe    252       1.3014     4.37                 0.1272                1.1083
#        Saratoga     25       1.3006     0.43                 0.1264                1.1076
#     Westchester    340       1.2912     5.89                 0.1170                1.0996
#         Suffolk    417       1.2024     7.23                 0.0282                1.0240
#        Onondaga    102       1.1949     1.77                 0.0207                1.0176
#  Saint Lawrence     23       1.1933     0.40                 0.0191                1.0163
#           Other    188       1.1924     3.26                 0.0182                1.0155
#            Erie    259       1.1795     4.49                 0.0053                1.0045
#      Chautauqua     40       1.1731     0.69                -0.0011                0.9991
#          Warren     38       1.1694     0.66                -0.0048                0.9959
#       Jefferson     21       1.1649     0.36                -0.0093                0.9921
#          Broome     57       1.1618     0.99                -0.0124                0.9894
#      Rensselaer     30       1.1445     0.52                -0.0297                0.9747
#          Albany     89       1.1331     1.54                -0.0411                0.9650
#           Bronx    573       1.1161     9.93                -0.0581                0.9505
#          Nassau    572       1.1115     9.92                -0.0627                0.9466
#          Queens    537       1.0993     9.31                -0.0749                0.9362
#         Steuben     33       1.0790     0.57                -0.0952                0.9189
#        Cortland     22       1.0775     0.38                -0.0967                0.9176
#        New York    774       1.0488    13.42                -0.1254                0.8932
#        Richmond    206       1.0470     3.57                -0.1272                0.8917
#          Ulster     29       1.0204     0.50                -0.1538                0.8690
#         Chemung     35       0.9980     0.61                -0.1762                0.8499
#           Wayne     20       0.8738     0.35                -0.3004                0.7442
#         Genesee     22       0.8027     0.38                -0.3715                0.6836
#
# --- permanent_facility_id ---
# permanent_facility_id  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
# 70 or Older   2788       1.3558    48.33                 0.1816                1.1547
#       50-69   1603       1.1609    27.79                -0.0133                0.9887
#       30-49    489       0.9624     8.48                -0.2118                0.8196
#        0-17    733       0.7488    12.71                -0.4254                0.6377
#       18-29    156       0.7284     2.70                -0.4458                0.6203
#
# --- zip_code ---
# zip_code  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#      129     23       1.5771     0.40                 0.4029                1.3431
#      106     25       1.4991     0.43                 0.3249                1.2767
#      147     32       1.4659     0.55                 0.2917                1.2484
#      126     21       1.4253     0.36                 0.2511                1.2138
#      109    139       1.3388     2.41                 0.1646                1.1402
#      105    133       1.3360     2.31                 0.1618                1.1378
#      120     45       1.3304     0.78                 0.1562                1.1330
#      135     18       1.3231     0.31                 0.1489                1.1268
#      112    798       1.2962    13.83                 0.1220                1.1039
#      146    164       1.2948     2.84                 0.1206                1.1027
#      110     76       1.2646     1.32                 0.0904                1.0770
#      127     17       1.2624     0.29                 0.0882                1.0751
#      128     60       1.2546     1.04                 0.0804                1.0685
#      138     34       1.2521     0.59                 0.0779                1.0663
#      131     32       1.2513     0.55                 0.0771                1.0657
#      145     76       1.2471     1.32                 0.0729                1.0621
#      111     52       1.2452     0.90                 0.0710                1.0605
#      122     32       1.2410     0.55                 0.0668                1.0569
#      125    106       1.2402     1.84                 0.0660                1.0562
#      123     22       1.2241     0.38                 0.0499                1.0425
#      140    101       1.2167     1.75                 0.0425                1.0362
#      124     42       1.2160     0.73                 0.0418                1.0356
#      134     40       1.2109     0.69                 0.0367                1.0313
#      108     27       1.2048     0.47                 0.0306                1.0261
#      130     67       1.2012     1.16                 0.0270                1.0230
#      OOS    103       1.1945     1.79                 0.0203                1.0173
#    Other     34       1.1893     0.59                 0.0151                1.0129
#      117    480       1.1890     8.32                 0.0148                1.0126
#      144     79       1.1803     1.37                 0.0061                1.0052
#      118     19       1.1772     0.33                 0.0030                1.0026
#      142    147       1.1726     2.55                -0.0016                0.9986
#      119     88       1.1711     1.53                -0.0031                0.9974
#      107     78       1.1694     1.35                -0.0048                0.9959
#      113    310       1.1650     5.37                -0.0092                0.9922
#      132     40       1.1416     0.69                -0.0326                0.9722
#      141     57       1.1302     0.99                -0.0440                0.9625
#      136     47       1.1286     0.81                -0.0456                0.9612
#      104    700       1.1123    12.13                -0.0619                0.9473
#      114    226       1.1103     3.92                -0.0639                0.9456
#      103    213       1.0606     3.69                -0.1136                0.9033
#      121     52       1.0365     0.90                -0.1377                0.8827
#      100    434       1.0357     7.52                -0.1385                0.8820
#      137     34       1.0091     0.59                -0.1651                0.8594
#      148     65       1.0036     1.13                -0.1706                0.8547
#      115    237       0.9936     4.11                -0.1806                0.8462
#      149     22       0.9722     0.38                -0.2020                0.8280
#      133     19       0.9445     0.33                -0.2297                0.8044
#      116     47       0.9246     0.81                -0.2496                0.7874
#      NAS     56       0.7763     0.97                -0.3979                0.6611
#
# --- gender ---
# gender  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#    F/U   3204       1.2072    55.54                 0.0330                1.0281
#      M   2565       1.1330    44.46                -0.0412                0.9649
#
# --- race ---
#                   race  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                  White   2894       1.2385    50.16                 0.0643                1.0548
#           Multi-racial     74       1.1945     1.28                 0.0203                1.0173
# Black/African American   1210       1.1648    20.97                -0.0094                0.9920
#             Other Race   1591       1.0635    27.58                -0.1107                0.9057
#
# --- ethnicity ---
#            ethnicity  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#    Not Span/Hispanic   4135       1.2066    71.68                 0.0324                1.0276
# Multi-ethnic/Unknown    656       1.1784    11.37                 0.0042                1.0036
#     Spanish/Hispanic    978       1.0345    16.95                -0.1397                0.8810
#
# --- type_of_admission ---
#     type_of_admission  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
# Elective/Trauma/Other     49       1.5719     0.85                 0.3977                1.3387
#                Urgent    156       1.2387     2.70                 0.0645                1.0549
#             Emergency   5564       1.1689    96.45                -0.0053                0.9955
#
# --- patient_disposition ---
#                   patient_disposition  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#     Inpatient Rehabilitation Facility     59       2.1414     1.02                 0.9672                1.8237
#            Hospice - Medical Facility     15       1.9853     0.26                 0.8111                1.6908
#                               Expired     86       1.9463     1.49                 0.7721                1.6576
#                                 Other     49       1.8578     0.85                 0.6836                1.5822
#                  Skilled Nursing Home    655       1.8485    11.35                 0.6743                1.5743
#  Psychiatric Hospital or Unit of Hosp     27       1.6321     0.47                 0.4579                1.3900
# Facility w/ Custodial/Supportive Care     45       1.4947     0.78                 0.3205                1.2730
#          Home w/ Home Health Services   1023       1.4372    17.73                 0.2630                1.2240
#                     Home or Self Care   3603       0.9505    62.45                -0.2237                0.8095
#                   Short-term Hospital     60       0.7322     1.04                -0.4420                0.6236
#           Left Against Medical Advice    147       0.6719     2.55                -0.5023                0.5722
#
# --- ccsr_procedure_description ---
#                                ccsr_procedure_description  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                                    MECHANICAL VENTILATION     46       2.2361     0.80                 1.0619                1.9044
#        CHEST TUBE PLACEMENT AND THERAPEUTIC THORACENTESIS     18       2.1890     0.31                 1.0148                1.8642
#                                         AIRWAY INTUBATION     19       2.0979     0.33                 0.9237                1.7867
#                    VENOUS AND ARTERIAL CATHETER PLACEMENT     42       2.0666     0.73                 0.8924                1.7600
#                                                     Other    256       1.8015     4.44                 0.6273                1.5342
#                MEASUREMENT DURING CARDIAC CATHETERIZATION     23       1.6068     0.40                 0.4326                1.3684
#                                  NON-INVASIVE VENTILATION    431       1.5542     7.47                 0.3800                1.3236
#                                              HEMODIALYSIS     96       1.4847     1.66                 0.3105                1.2644
#                COMPUTERIZED TOMOGRAPHY (CT) WITH CONTRAST     28       1.4127     0.49                 0.2385                1.2031
#                   TRANSFUSION OF BLOOD AND BLOOD PRODUCTS     39       1.4108     0.68                 0.2366                1.2015
#             COMPUTERIZED TOMOGRAPHY (CT) WITHOUT CONTRAST     17       1.3000     0.29                 0.1258                1.1071
#                                           ULTRASONOGRAPHY    105       1.2772     1.82                 0.1030                1.0877
#                ADMINISTRATION OF ANTI-INFLAMMATORY AGENTS     75       1.2304     1.30                 0.0562                1.0479
#                             ADMINISTRATION OF ANTIBIOTICS    322       1.1816     5.58                 0.0074                1.0063
#                                           LUMBAR PUNCTURE     29       1.1534     0.50                -0.0208                0.9823
#                                ELECTROENCEPHALOGRAM (EEG)     30       1.0590     0.52                -0.1152                0.9019
#             ADMINISTRATION OF THERAPEUTIC SUBSTANCES, NEC    351       1.0584     6.08                -0.1158                0.9014
#                                                      None   2727       1.0533    47.27                -0.1209                0.8970
#                                      ISOLATION PROCEDURES   1005       1.0533    17.42                -0.1209                0.8970
# ADMINISTRATION OF NUTRITIONAL AND ELECTROLYTIC SUBSTANCES    110       0.9404     1.91                -0.2338                0.8009
#
# --- apr_drg_description ---
#                   apr_drg_description  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                                 Other     61       2.8590     1.06                 1.6848                2.4348
#                       OTHER PNEUMONIA   1639       1.3388    28.41                 0.1646                1.1402
# INFECTIONS OF UPPER RESPIRATORY TRACT   3748       1.0874    64.97                -0.0868                0.9261
#                         VIRAL ILLNESS    321       1.0278     5.56                -0.1464                0.8753
#
# --- apr_mdc_description ---
#                                              apr_mdc_description  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                 DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM   1672       1.3676    28.98                 0.1934                1.1647
# EAR, NOSE, MOUTH, THROAT AND CRANIOFACIAL DISEASES AND DISORDERS   3769       1.0976    65.33                -0.0766                0.9348
# INFECTIOUS AND PARASITIC DISEASES, SYSTEMIC OR UNSPECIFIED SITES    328       1.0687     5.69                -0.1055                0.9102
#
# --- apr_severity_of_illness_description ---
# apr_severity_of_illness_description  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                             Extreme    380       2.1094     6.59                 0.9352                1.7965
#                               Major   2667       1.3633    46.23                 0.1891                1.1610
#                            Moderate   2050       0.9274    35.53                -0.2468                0.7898
#                               Minor    672       0.6480    11.65                -0.5262                0.5519
#
# --- apr_risk_of_mortality ---
# apr_risk_of_mortality  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#               Extreme    428       1.9279     7.42                 0.7537                1.6419
#                 Major   2093       1.4454    36.28                 0.2712                1.2310
#              Moderate   1590       1.0428    27.56                -0.1314                0.8881
#                 Minor   1658       0.7634    28.74                -0.4108                0.6501
#
# --- apr_medical_surgical_description ---
# apr_medical_surgical_description  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                         Surgical     46       3.0454      0.8                 1.8712                2.5936
#                          Medical   5723       1.1592     99.2                -0.0150                0.9872
#
# --- payment_typology_1 ---
#        payment_typology_1  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                  Medicare   3448       1.3355    59.77                 0.1613                1.1374
#       Miscellaneous/Other     60       1.1319     1.04                -0.0423                0.9640
# Managed Care, Unspecified     63       0.9664     1.09                -0.2078                0.8230
#                  Medicaid   1261       0.9471    21.86                -0.2271                0.8066
#  Private Health Insurance    544       0.9345     9.43                -0.2397                0.7959
#    Blue Cross/Blue Shield    309       0.8742     5.36                -0.3000                0.7445
#                  Self-Pay     84       0.8077     1.46                -0.3665                0.6879
#
# --- payment_typology_2 ---
#        payment_typology_2  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#       Miscellaneous/Other     29       1.7329     0.50                 0.5587                1.4758
#  Private Health Insurance    445       1.3601     7.71                 0.1859                1.1583
#    Blue Cross/Blue Shield    342       1.3302     5.93                 0.1560                1.1329
#                  Medicare    693       1.3097    12.01                 0.1355                1.1154
#                  Medicaid   1443       1.2855    25.01                 0.1113                1.0948
#    Federal/State/Local/VA     32       1.2502     0.55                 0.0760                1.0647
# Managed Care, Unspecified     18       1.1067     0.31                -0.0675                0.9425
#                      None   2490       1.0301    43.16                -0.1441                0.8773
#                  Self-Pay    277       0.9969     4.80                -0.1773                0.8490
#
# --- payment_typology_3 ---
#       payment_typology_3  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                 Medicaid    329       1.4053     5.70                 0.2311                1.1968
# Private Health Insurance     97       1.3606     1.68                 0.1864                1.1587
#      Miscellaneous/Other     53       1.2641     0.92                 0.0899                1.0766
#                 Self-Pay    440       1.2503     7.63                 0.0761                1.0648
#   Blue Cross/Blue Shield     44       1.2382     0.76                 0.0640                1.0545
#                     None   4806       1.1461    83.31                -0.0281                0.9761
#
# --- emergency_department_indicator ---
# emergency_department_indicator  count  target_mean  percent  diff_from_global_mean  ratio_to_global_mean
#                              Y   5371       1.1773     93.1                 0.0031                1.0026
#                              N    398       1.1323      6.9                -0.0419                0.9643

# %%
# MI scores
X_train_encoded = X_train.copy()
for col in features:
    le = LabelEncoder()
    X_train_encoded[col] = le.fit_transform(X_train[col])

mi_scores = mutual_info_regression(X_train_encoded, y_train, discrete_features = True)
mi = pd.Series(mi_scores, index = X_train.columns).sort_values(ascending = False)
print(mi)
# Out:
# patient_disposition                    0.117137
# apr_severity_of_illness_description    0.107915
# apr_risk_of_mortality                  0.102504
# ccsr_procedure_description             0.052794
# permanent_facility_id                  0.041857
# age_group                              0.040202
# apr_drg_description                    0.030254
# payment_typology_1                     0.027595
# payment_typology_2                     0.024780
# apr_medical_surgical_description       0.017885
# race                                   0.016149
# hospital_county                        0.014483
# apr_mdc_description                    0.010603
# gender                                 0.008564
# ethnicity                              0.005608
# payment_typology_3                     0.005247
# health_service_area                    0.005121
# emergency_department_indicator         0.004925
# zip_code                               0.004727
# type_of_admission                      0.001388
# dtype: float64

# %% [markdown]
# MI scores for `type_of_admission`, `ethnicity`, and `gender` are effectively zero. For `type_of_admission` and `ethnicity`, this reflects large class imbalance (96% and 72% in dominant categories) combined with small effect sizes. For `gender`, univariate analysis shows minimal differences in mean log(LoS) across categories.

# %%
level_counts = X_train[features].nunique()

print(level_counts)
# Out:
# health_service_area                      8
# hospital_county                         33
# permanent_facility_id                  116
# age_group                                5
# zip_code                                49
# gender                                   2
# race                                     4
# ethnicity                                3
# type_of_admission                        3
# patient_disposition                     11
# ccsr_procedure_description              20
# apr_drg_description                      4
# apr_mdc_description                      3
# apr_severity_of_illness_description      4
# apr_risk_of_mortality                    4
# apr_medical_surgical_description         2
# payment_typology_1                       7
# payment_typology_2                       9
# payment_typology_3                       6
# emergency_department_indicator           2
# dtype: int64

# %%
level_counts = X_val[features].nunique()

print(level_counts)
# Out:
# health_service_area                      8
# hospital_county                         33
# permanent_facility_id                  115
# age_group                                5
# zip_code                                49
# gender                                   2
# race                                     4
# ethnicity                                3
# type_of_admission                        3
# patient_disposition                     10
# ccsr_procedure_description              18
# apr_drg_description                      4
# apr_mdc_description                      3
# apr_severity_of_illness_description      4
# apr_risk_of_mortality                    4
# apr_medical_surgical_description         2
# payment_typology_1                       7
# payment_typology_2                       9
# payment_typology_3                       6
# emergency_department_indicator           2
# dtype: int64

# %%
level_counts = X_test[features].nunique()

print(level_counts)
# Out:
# health_service_area                      8
# hospital_county                         33
# permanent_facility_id                  116
# age_group                                5
# zip_code                                49
# gender                                   2
# race                                     4
# ethnicity                                3
# type_of_admission                        3
# patient_disposition                     11
# ccsr_procedure_description              19
# apr_drg_description                      4
# apr_mdc_description                      3
# apr_severity_of_illness_description      4
# apr_risk_of_mortality                    4
# apr_medical_surgical_description         2
# payment_typology_1                       7
# payment_typology_2                       9
# payment_typology_3                       6
# emergency_department_indicator           2
# dtype: int64

# %%
# target encoding

# initialize; target_type = 'continuous' for regression; smooth ='auto' handles unseen categories and adds regularization
encoder = TargetEncoder(target_type = 'continuous', smooth = 'auto', random_state = 42)

# fit on training data only
X_train_encoded = encoder.fit_transform(X_train, y_train)

# transform validation and test (handles unseen categories automatically)
X_val_encoded = encoder.transform(X_val)
X_test_encoded = encoder.transform(X_test)

# convert back to DataFrames
X_train_encoded = pd.DataFrame(X_train_encoded, columns = X_train.columns, index = X_train.index)
X_val_encoded = pd.DataFrame(X_val_encoded, columns = X_val.columns, index = X_val.index)
X_test_encoded = pd.DataFrame(X_test_encoded, columns = X_test.columns, index = X_test.index)

# %%
target_encoded_data = {
    # data
    'X_train': X_train_encoded,
    'X_val': X_val_encoded,
    'X_test': X_test_encoded,
    'y_train': y_train,
    'y_val': y_val,
    'y_test': y_test,

    # original, non-encoded features
    'X_train_orig': X_train,
    'X_val_orig': X_val,
    'X_test_orig': X_test,

    # metadata
    'feature_names': X_train.columns.tolist(),
    'category_mappings': category_mappings,

    # encoding-specific information
    'encoder': encoder,
    'encoding_method': 'standard_target_encoding'    
}

with open('../data/temp/target_encoded_data.pkl', 'wb') as f:
    pickle.dump(target_encoded_data, f)

# %%
# custom target encoding (mean * median)

stats = {}  # dictionary to store mean*median per column

X_train_encoded = pd.DataFrame(index = X_train.index)
for col in features:
    grouped = y_train.groupby(X_train[col]).agg(['mean', 'median'])
    grouped['mean_median'] = grouped['mean'] * grouped['median']
    
    # store the values
    stats[col] = grouped['mean_median'].to_dict()
    
    # apply to training data
    X_train_encoded[col] = X_train[col].map(grouped['mean_median'])

# handle unseen categories (use global mean*median as fallback)
global_mean = y_train.mean()
global_median = y_train.median()
global_encoding = global_mean * global_median

# apply to validation data
X_val_encoded = pd.DataFrame(index = X_val.index)
for col in features:
    X_val_encoded[col] = X_val[col].map(stats[col]).fillna(global_encoding)

# apply to test data
X_test_encoded = pd.DataFrame(index = X_test.index)
for col in features:
    X_test_encoded[col] = X_test[col].map(stats[col]).fillna(global_encoding)

# %%
# save data with custom encoding
custom_target_encoded_data = {
    # data
    'X_train': X_train_encoded,
    'X_val': X_val_encoded,
    'X_test': X_test_encoded,
    'y_train': y_train,
    'y_val': y_val,
    'y_test': y_test,

    # metadata
    'feature_names': X_train.columns.tolist(),
    'category_mappings': category_mappings,

    # encoding-specific information
    'stats': stats,  # custom encoding mappings
    'global_encoding': global_encoding,  # fallback for unseen categories
    'encoding_method': 'mean_times_median_encoding'
}

with open('../data/temp/custom_target_encoded_data.pkl', 'wb') as f:
    pickle.dump(custom_target_encoded_data, f)
